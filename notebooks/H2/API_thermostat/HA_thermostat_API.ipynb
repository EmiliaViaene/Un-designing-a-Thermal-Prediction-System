# %% [markdown]
# # HH2: get thermostat presets and sensor readings
# ### Remeha thermostat API via Home Assistant) --> send to DataFoundry dataset

# %%
from requests import get

url = "https://qg0vp5bktmmxqszx5ssw24gevftf6bzr.ui.nabu.casa/api/states/climate.algemeen"
headers = {
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJhM2QzMmY1Yzg2NjM0NDM4OWUwMTg3ZWZmYzEyYWI3MCIsImlhdCI6MTcyNjY3Mzg4MCwiZXhwIjoyMDQyMDMzODgwfQ.o9iE-sGgJYZkoBEvfwL1NMuBDbiJUwp4rI5YgnKL-vE",
    "content-type": "application/json",
}

response = get(url, headers=headers)
print(response.text)
# Out:
# {"entity_id":"climate.algemeen","state":"heat","attributes":{"hvac_modes":["off","heat","auto"],"min_temp":5.0,"max_temp":30.0,"preset_modes":["clock_program_1","clock_program_2","clock_program_3"],"current_temperature":21.0,"temperature":13.0,"hvac_action":"idle","preset_mode":"manual","friendly_name":"Algemeen","supported_features":401},"last_changed":"2024-09-19T04:13:41.955854+00:00","last_reported":"2024-09-19T05:04:43.983313+00:00","last_updated":"2024-09-19T05:04:43.983313+00:00","context":{"id":"01J84AP6EFD8NBZ0KYC6EX4J7H","parent_id":null,"user_id":null}}
